# %% [markdown]
# <a href="https://colab.research.google.com/github/bruckman/Gamma_Factory/blob/main/pdf_CLT_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import collections as collections
from matplotlib.patches import Polygon

def func(x):
    #return x * np.exp(-x)
    #return x*x * np.exp(-x*x)
    #return 0.0*x+0.1666666
    #return x*x
    #y =0*x +1
    #for i in range(0,len(x)-1):
    #   if x[i]>-2.2 and x[i]<2.2:
    #      y[i]=0
    #return y
    return np.abs(x)
    #return -0.125*x+0.5

#x = np.linspace(0, 6, 120)
x = np.linspace(-3, 3, 120)
#x = np.linspace(-1, 3, 120)
#x = np.linspace(0, 4, 120)
y = func(x)
z = func(x)

for n in range(0,9):

  fig, ax = plt.subplots()
  ax.plot(x, z, 'r', linewidth=2)
  for i in x:
      ax.vlines( x, 0, z, linestyles='solid', colors='ivory', linewidth=3)
  ax.set_ylim(bottom=0)


  #ax.text(4.0, 0.25, r"n=%d"%n, horizontalalignment='center', fontsize=20)
  ax.text(2.5, z.max()*0.5, r"n=%d"%np.power(2,n), horizontalalignment='center', fontsize=20)


  fig.text(0.9, 0.05, '$x$', fontsize=14)
  fig.text(0.1, 0.9, 'PDF', fontsize=14)

  ax.spines['right'].set_visible(False)
  ax.spines['top'].set_visible(False)
  ax.xaxis.set_ticks_position('bottom')

  ax.set_xticks((1.33333, ))
  ax.set_xticklabels(('$\\langle x \\rangle$', ), horizontalalignment='center', verticalalignment='center_baseline', fontsize=14)
  ax.set_yticks([])

  #ax.vlines([1, 2], 0, [func(1),func(2)], linestyles='--', colors=['red','black'])

  # plt.axis('off')

  plt.savefig("pdf_mean_3_%d.png"%n, dpi=150)

  plt.show()

  zz = np.convolve(z, z, mode='full')
  # Note: convolution adds the random variables and NOT takes the average
  # Need to be contracted by a fator 2:
  #print(len(z), len(zz))
  #print(z[0], z[len(z)-1])
  for k in range(0,len(z)-1):
      z[k] = zz[2*k]
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
